# %%
import pandas as pd
import numpy as np

# %%
users = pd.read_csv('users.csv')
users.head()
# Out:
#                login                  name  \
# 0          AlexGyver                  Alex
# 1       carlcastanas  Carl Andrew Castañas
# 2  sergeyshaykhullin    Sergey Shaykhullin
# 3  alexey-goloburdin     Alexey Goloburdin
# 4     richardroberti       Richard Roberti
#
#                                       company        location  \
# 0                                         NaN          Moscow
# 1                                  ICREATECHS          Moscow
# 2                                         NaN          Moscow
# 3  TO.DIGITAL, SALESBEAT.PRO, DIGITALIZE.TEAM  Moscow, Russia
# 4                                      E CORP  Moscow, Russia
#
#                email hireable  \
# 0  alex@alexgyver.ru     none
# 1                NaN     true
# 2                NaN     none
# 3       sterx@rl6.ru     none
# 4                NaN     none
#
#                                                  bio  public_repos  followers  \
# 0  Инженер, изобретатель, ардуинщик, блогер, люби...           147       3317
# 1                                                NaN            56       2860
# 2                 Kubernetes 👀 .NET 👀 Rust 👀 Next.js            16       1983
# 3                                                NaN            27       1853
# 4                                             DevOps             4       1778
#
#    following            created_at
# 0          0  2016-08-17T22:15:28Z
# 1          3  2021-08-17T07:52:33Z
# 2          3  2019-01-23T16:40:07Z
# 3          0  2012-06-26T20:23:25Z
# 4          4  2023-01-27T22:09:59Z

# %%
# users['hireable'] = users['hireable'].fillna(False).astype(bool)
# # users['hireable'] = users['hireable'].replace(True, 'true')

# %%
top5 = users.sort_values(by='followers', ascending=False).head()
print(','.join(top5['login'].tolist()))
# Out:
# AlexGyver,carlcastanas,sergeyshaykhullin,alexey-goloburdin,richardroberti

# %%
users
# Out:
#                  login                  name  \
# 0            AlexGyver                  Alex
# 1         carlcastanas  Carl Andrew Castañas
# 2    sergeyshaykhullin    Sergey Shaykhullin
# 3    alexey-goloburdin     Alexey Goloburdin
# 4       richardroberti       Richard Roberti
# ..                 ...                   ...
# 454             thekvs    Konstantin Sorokin
# 455    VTroyanGolovyan                 vhdev
# 456     gregor-tokarev               Gregor
# 457             DKunin          Dmitri Kunin
# 458     antonydevanchi        Anton Piskunov
#
#                                         company        location  \
# 0                                           NaN          Moscow
# 1                                    ICREATECHS          Moscow
# 2                                           NaN          Moscow
# 3    TO.DIGITAL, SALESBEAT.PRO, DIGITALIZE.TEAM  Moscow, Russia
# 4                                        E CORP  Moscow, Russia
# ..                                          ...             ...
# 454                                         NaN  Moscow, Russia
# 455  MOSCOW INSTITUTE OF PHYSICS AND TECHNOLOGY          Moscow
# 456                                   PROCOLLAB          Moscow
# 457                                       AVITO  Russia, Moscow
# 458                            PSKNV, KONSOLPRO  Russia, Moscow
#
#                     email hireable  \
# 0       alex@alexgyver.ru     none
# 1                     NaN     true
# 2                     NaN     none
# 3            sterx@rl6.ru     none
# 4                     NaN     none
# ..                    ...      ...
# 454        kvs@sigterm.ru     true
# 455                   NaN     true
# 456        e@tokarev.work     true
# 457                   NaN     none
# 458  anton@piskunov.email     true
#
#                                                    bio  public_repos  \
# 0    Инженер, изобретатель, ардуинщик, блогер, люби...           147
# 1                                                  NaN            56
# 2                   Kubernetes 👀 .NET 👀 Rust 👀 Next.js            16
# 3                                                  NaN            27
# 4                                               DevOps             4
# ..                                                 ...           ...
# 454                                                NaN            49
# 455                            C++ developer. \r\n\r\n            28
# 456                                         20 y.o SWE            41
# 457  Technical Unit Leader / Javascript developer a...           157
# 458     CISO at @konsolpro and self-employed at @PSKNV           159
#
#      followers  following            created_at
# 0         3317          0  2016-08-17T22:15:28Z
# 1         2860          3  2021-08-17T07:52:33Z
# 2         1983          3  2019-01-23T16:40:07Z
# 3         1853          0  2012-06-26T20:23:25Z
# 4         1778          4  2023-01-27T22:09:59Z
# ..         ...        ...                   ...
# 454         51          5  2010-03-07T17:07:25Z
# 455         51         30  2017-07-22T15:39:00Z
# 456         51         21  2019-07-01T05:07:15Z
# 457         51        200  2011-08-22T18:22:12Z
# 458         51        169  2011-02-10T03:49:53Z
#
# [459 rows x 11 columns]

# %%
users['created_at'] = pd.to_datetime(users['created_at'])
top_earliest = users.sort_values(by='created_at').head()
print(','.join(top_earliest['login'].tolist()))
# Out:
# maxlapshin,veged,alexeyr,alec-c4,alno

# %%
repos = pd.read_csv('repositories.csv')
repos.head()
# Out:
#        login                      full_name            created_at  \
# 0  AlexGyver           AlexGyver/WaterDance  2024-04-04T14:48:56Z
# 1  AlexGyver            AlexGyver/BallClock  2024-09-24T13:32:09Z
# 2  AlexGyver          AlexGyver/RipCalendar  2024-08-16T15:49:03Z
# 3  AlexGyver              AlexGyver/AiFrame  2024-07-17T11:52:58Z
# 4  AlexGyver  AlexGyver/alexgyver.github.io  2019-08-02T13:07:33Z
#
#    stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0                 4               4         C++          True      True
# 1                 8               8         C++          True      True
# 2                10              10         C++          True      True
# 3                14              14           C          True      True
# 4                43              43  JavaScript          True      True
#
#   license_name
# 0          mit
# 1          mit
# 2          mit
# 3          mit
# 4          NaN

# %%
repos['license_name'].value_counts().head(3)
# Out:
# license_name
# mit           6231
# other         1640
# apache-2.0    1468
# Name: count, dtype: int64

# %%
users['company'].value_counts().head(1)
# Out:
# company
# YANDEX    22
# Name: count, dtype: int64

# %%
repos['language'].value_counts().head(1)
# Out:
# language
# JavaScript    2968
# Name: count, dtype: int64

# %%
users_after_2020 = users[users['created_at'] > '2020-01-01']
users_after_2020.head()
# Out:
#              login                  name     company         location email  \
# 1     carlcastanas  Carl Andrew Castañas  ICREATECHS           Moscow   NaN
# 4   richardroberti       Richard Roberti      E CORP   Moscow, Russia   NaN
# 6         Robi2810                Rodion    SBERBANK           Moscow   NaN
# 8        PHPTCloud          Yudov Alexei         NaN           Moscow   NaN
# 14        coffinxp                coffin         NaN  Russia (moscow)   NaN
#
#    hireable                                      bio  public_repos  followers  \
# 1      true                                      NaN            56       2860
# 4      none                                   DevOps             4       1778
# 6      none                             DevOps @Sber            31       1678
# 8      none  PHP & Golang software backend develeper             7       1344
# 14     none                      Security Researcher            11       1038
#
#     following                created_at
# 1           3 2021-08-17 07:52:33+00:00
# 4           4 2023-01-27 22:09:59+00:00
# 6       10241 2022-02-09 14:28:22+00:00
# 8        1205 2020-04-20 06:17:21+00:00
# 14          0 2024-07-31 01:54:58+00:00

# %%
repos_2020 = repos[repos['login'].isin(users_after_2020['login'].tolist())]
repos_2020['language'].value_counts().head()
# Out:
# language
# JavaScript    227
# Python        163
# CSS           116
# HTML          114
# TypeScript     87
# Name: count, dtype: int64

# %%
avg_stars = repos.groupby('language')['stargazers_count'].mean()
top_lang = avg_stars.idxmax()
top_stars = avg_stars.max()
print(top_lang, top_stars)
# Out:
# Pascal 501.7878787878788

# %%
users['leader_strength'] = users['followers'] / (1 + users['following'])
top5_lead = users.sort_values(by='leader_strength', ascending=False).head()
print(','.join(top5_lead['login'].tolist()))
# Out:
# AlexGyver,alexey-goloburdin,yandex,esokolov,yandexdataschool

# %%
correlation = users['followers'].corr(users['public_repos'])
correlation
# Out:
# 0.05132356900009497

# %%
import csv
followers = []
public_repos = []
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        followers_count = int(row['followers'])
        public_repos_count = int(row['public_repos'])
        followers.append(followers_count)
        public_repos.append(public_repos_count)
if len(followers) > 1 and len(public_repos) > 1:
    slope, intercept = np.polyfit(public_repos, followers, 1)

    print(f"{slope:.3f}")
else:
    print("Error")
# Out:
# 0.210

# %%
correlation = repos[["has_projects", "has_wiki"]].corr()
correlation
# Out:
#               has_projects  has_wiki
# has_projects      1.000000  0.344643
# has_wiki          0.344643  1.000000

# %%
correlation_projects_wiki = repos['has_projects'].astype(int).corr(repos['has_wiki'].astype(int))
print("Ans 11 : Correlation between projects_enabled and wiki_enabled:", round(correlation_projects_wiki, 3))
# Out:
# Ans 11 : Correlation between projects_enabled and wiki_enabled: 0.345

# %%
# q12
hireable_avg_following = users[users['hireable'] == "true"]['following'].mean()
non_hireable_avg_following = users[users['hireable'] == "none"]['following'].mean()
difference = hireable_avg_following - non_hireable_avg_following
difference
# Out:
# -29.354994259471873

# %%
# q13
from sklearn.linear_model import LinearRegression
users_with_bio = users[(users['bio'].notna()) & (users['bio'] != '')].copy()
users_with_bio.loc[:, 'bio_len'] = users_with_bio['bio'].str.len()

X = users_with_bio['bio_len'].values.reshape(-1,1)
y = users_with_bio['followers']

lr2 = LinearRegression()
lr2.fit(X, y)
lr2.coef_[0]
# Out:
# 0.11825093635766644

# %%
users["bio_length"] = users["bio"].apply(
    lambda x: len(str(x).split()) if str(x).strip() != "" else 0)
users[users["bio_length"] > 0][["bio_length", "followers"]].corr()
# Out:
#             bio_length  followers
# bio_length    1.000000   0.024765
# followers     0.024765   1.000000

# %%
bio_length, followers = users[users["bio_length"]
                              > 0]["bio_length"], users[users["bio_length"] > 0]["followers"]
slope, intercept = np.polyfit(bio_length, followers, 1)
round(slope, 3)
# Out:
# 1.354

# %%
import csv
from collections import Counter
from datetime import datetime

weekend_repo_counts = Counter()

with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        created_at = row.get('created_at', '')
        if created_at:
            created_date = datetime.fromisoformat(created_at[:-1])

            if created_date.weekday() in [5, 6]:
                user_login = row['login']
                weekend_repo_counts[user_login] += 1

top_users = weekend_repo_counts.most_common(5)

top_logins = [user[0] for user in top_users]

print(','.join(top_logins))
# Out:
# VN0,kuggaa,reverse-ex,Mirocow,vslinko

# %%
# q15
fraction_hierable = users[users['hireable'] == 'true']['email'].notna().mean()
fraction_non_hierable = users[users['hireable'] == 'none']['email'].notna().mean()
diff = fraction_hierable - fraction_non_hierable
diff
# Out:
# 0.1885648679678531

# %%
fraction_hierable = users[users['hireable'] == True]['email'].notna().mean()
fraction_non_hierable = users[users['hireable']
                              == False]['email'].notna().mean()
diff = fraction_hierable - fraction_non_hierable
round(diff, 3)
# Out:
# nan

# %%
new_users = users[users['name'].notna()].copy()
new_users['surname'] = new_users['name'].str.split().str[-1].str.strip()
surname_counts = new_users['surname'].value_counts()
max_count = surname_counts.max()
common_surnames = surname_counts[surname_counts == max_count].index.tolist()
common_surnames.sort()
print(','.join(common_surnames))
# Out:
# Romanov

# %%
repos.isna().sum()
# Out:
# login                   0
# full_name               0
# created_at              0
# stargazers_count        0
# watchers_count          0
# language             6452
# has_projects            0
# has_wiki                0
# license_name        12695
# dtype: int64
